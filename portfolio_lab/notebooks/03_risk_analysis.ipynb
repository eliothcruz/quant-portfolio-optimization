# %% [markdown]
# # 03 — Risk Analysis
#
# VaR, TVaR, and stress scenario analysis.
#
# **Status:** Phase 2 — not yet implemented.
#
# > This notebook does not contain project logic. All logic lives in `src/`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.data.loader import load_processed

# %%
# Placeholder — risk analysis to be added in Phase 2
returns = load_processed('returns.csv')
print(f"Returns loaded: {returns.shape}")
print("VaR / TVaR: Phase 2")
